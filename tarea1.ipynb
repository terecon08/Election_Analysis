# %%
lista1 = ["país", ["México", "Argentina", "Colombia", "Bolivia"], 13, "bien", [11, 22, 33]]
lista2 = [30.5, 8.2, 5.7, 9.3, 22.5]
lista3 = ["suma", [28.4, 7.9, 6.1, 10.2, 21.8], "ok"]
diccionario1 = {
    "edades": [12, 15, 13, 12, 13, 14, 12, 11, 15, 16],
    "estaturas": [150, 175, 160, 180, 170, 165, 155, 172, 168, 178]
}
import statistics
print(lista1[1][1], lista1[4][1], lista1[2])
print(lista2[3])
sumalista2=sum(lista2)
print(sumalista2)
sumasublista3= sum(lista3[1])
print(sumasublista3)
print(diccionario1["edades"])
sumadictionario1edades= sum(diccionario1["edades"])
print(sumadictionario1edades)
print(diccionario1["estaturas"])
mediadictionario1estaturas= statistics.mean(diccionario1["estaturas"])
print(mediadictionario1estaturas)
# Out:
# Argentina 22 13
# 9.3
# 76.2
# 74.4
# [12, 15, 13, 12, 13, 14, 12, 11, 15, 16]
# 133
# [150, 175, 160, 180, 170, 165, 155, 172, 168, 178]
# 167.3

# %% [markdown]
# Tarea de listas:
#
# lista1 = ["país", ["México", "Argentina", "Colombia", "Bolivia"], 13, "bien", [11, 22, 33]]
# lista2 = [30.5, 8.2, 5.7, 9.3, 22.5]
# lista3 = ["suma", [28.4, 7.9, 6.1, 10.2, 21.8], "ok"]
#
# diccionario1 = {
#     "edades": [12, 15, 13, 12, 13, 14, 12, 11, 15, 16],
#     "estaturas": [150, 175, 160, 180, 170, 165, 155, 172, 168, 178]
# }
#
# Estos son los datos:
# - Obtener de la *lista1* la palabra "Argentina", el número 22 y el número 13
# - Obtener de la *lista2* el número 9.3
# - Obtener la suma de la *lista 2*
# - Obtener la suma de la sublista dentro de la *lista3*
# - Obtener del *diccionario1* la lista de edades
# - Obtener del *diccionario1* la suma de edades
# - Obtener del *diccionario1* la lista de estaturas
# - Obtener del *diccionario1* el promedio de estaturas
